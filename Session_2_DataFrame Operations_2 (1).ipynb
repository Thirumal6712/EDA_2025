# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\omkar\OneDrive\Documents\Gen_AI\Data_files\Visadataset.csv")

# %%
bank_df=pd.read_csv(r"C:\Users\omkar\OneDrive\Documents\Gen_AI\Data_files\bank.csv",
            sep=';')

# %%
- shape

- size

- len

- columns

- dtypes

- isnull

- info

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - series looks like dataframe
#
# - dataframe has column names matrix kind
#
# - Series only index and its value
#
# - Series like a dictionary key and values

# %%
visa_df.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
list(visa_df.dtypes.items())
# Out:
# [('case_id', dtype('O')),
#  ('continent', dtype('O')),
#  ('education_of_employee', dtype('O')),
#  ('has_job_experience', dtype('O')),
#  ('requires_job_training', dtype('O')),
#  ('no_of_employees', dtype('int64')),
#  ('yr_of_estab', dtype('int64')),
#  ('region_of_employment', dtype('O')),
#  ('prevailing_wage', dtype('float64')),
#  ('unit_of_wage', dtype('O')),
#  ('full_time_position', dtype('O')),
#  ('case_status', dtype('O'))]

# %% [markdown]
# **Make a Dataframe**

# %%
pd.DataFrame(visa_df.dtypes)
# Out:
#                              0
# case_id                 object
# continent               object
# education_of_employee   object
# has_job_experience      object
# requires_job_training   object
# no_of_employees          int64
# yr_of_estab              int64
# region_of_employment    object
# prevailing_wage        float64
# unit_of_wage            object
# full_time_position      object
# case_status             object

# %%
keys=visa_df.dtypes.keys()
values=visa_df.dtypes.values
pd.DataFrame(zip(keys,values),
            columns=['Column name','Data type'])
# Out:
#               Column name Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# - When we have a dictionary
#
# - First makes in to keys and values seperate
#
# - Then create a dataframe

# %% [markdown]
# **task-1: seperate categorical columns and numerical**

# %%
dict1={'A':1,
      'B':2,
      'a':3,
      'b':4}
for i,j in dict1.items():
    #print(i,j)
    if i.isupper():
        print(j)
# Out:
# 1
# 2

# %%
dict(visa_df.dtypes)
# iterate two i,j
# apply the condition
# if j=='object'
# append i in a list
# else
#  append i in list
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dtypes=dict(visa_df.dtypes)
cat,num=[],[]
for i,j in dtypes.items():
    if j=='object':
        cat.append(i)
    else:
        num.append(i)

# %%
dtypes=dict(visa_df.dtypes)
cat=[i for i,j in dtypes.items() if j=='object']
num=[i for i,j in dtypes.items() if j!='object']

# %% [markdown]
# **select_dtypes**

# %%
cat=visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# import the packages
# read the data
# selectdtypes

# %% [markdown]
# **Data selection**
#
# - take
#
# - loc
#
# - iloc

# %%
# select 100,200,300 rows data
rows=[100,200,300]
visa_df.take(rows,axis=0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=[1,5]
visa_df.take(cols,axis=1).take(rows,axis=0)
# Out:
#     continent  no_of_employees
# 100      Asia             2227
# 200      Asia             3282
# 300      Asia             3268

# %% [markdown]
# - Manual counting index of columns
#
# - At a time i can not select rows and columns,we need to do two takes

# %% [markdown]
# **iloc**

# %% [markdown]
# iloc[rows,columns]
#
# iloc[start:stop:step,start:stop:step]

# %%
visa_df.iloc[1:5,2:5]
# Out:
#   education_of_employee has_job_experience requires_job_training
# 1              Master's                  Y                     N
# 2            Bachelor's                  N                     Y
# 3            Bachelor's                  N                     N
# 4              Master's                  Y                     N

# %%
visa_df.iloc[1:5,5] # w
visa_df.iloc[4,2:5] # w
visa_df.iloc[1:5,[2,6,7]] # w
visa_df.iloc[[100,200,300],2:5] # w
visa_df.iloc[[100,200,300],[2,6,7]] # w
visa_df.iloc[100,5] # w
visa_df.iloc[100] # w
visa_df.iloc[:,5] # w
visa_df.iloc[5,:] # w

# %%
# selecting a particular column
visa_df.iloc[:,5]
# Out:
# 0        14513
# 1         2412
# 2        44444
# 3           98
# 4         1082
#          ...
# 25475     2601
# 25476     3274
# 25477     1121
# 25478     1918
# 25479     3195
# Name: no_of_employees, Length: 25480, dtype: int64

# %%
#visa_df.iloc[[:,5]]
visa_df.iloc[:,[5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
visa_df.iloc[:,5]  # series
visa_df.iloc[:,[5]] # df

# %%
visa_df.iloc[:,'no_of_employees']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File E:\Anaconda\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 visa_df.iloc[:,'no_of_employees']
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\indexing.py:968, in _LocationIndexer._validate_tuple_indexer(self, key)
#     966         self._validate_key(k, i)
#     967     except ValueError as err:
# --> 968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#     972 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %% [markdown]
# - take
#
#     - Manual counting
#
#     - At a time we can not select rows and columns
#
# - iloc
#
#     - Manual counting
#
# - loc

# %%
visa_df.loc[:,'no_of_employees']
# Out:
# 0        14513
# 1         2412
# 2        44444
# 3           98
# 4         1082
#          ...
# 25475     2601
# 25476     3274
# 25477     1121
# 25478     1918
# 25479     3195
# Name: no_of_employees, Length: 25480, dtype: int64

# %%
visa_df.loc[1:5,<>] 
visa_df.loc[4,2:<>] 
visa_df.loc[1:5,[<>]] 
visa_df.loc[[100,200,300],:] 
visa_df.loc[[100,200,300],[<>]] 
visa_df.loc[100,<>] 
visa_df.loc[100] 
visa_df.loc[:,<>] 
visa_df.loc[5,:]
